# %%
import pandas as pd

# %%
file_path='DH8D_valid.csv.xz'
df=pd.read_csv(file_path,compression='xz')

# %%
df
# Out:
#               time  timestep  maxtimestep  icao24  outliers  callsign  \
# 0       1504225961         0          795      25  0.017673       252
# 1       1504225976        15          795      25  0.017673       252
# 2       1504225991        30          795      25  0.017673       252
# 3       1504226006        45          795      25  0.017673       252
# 4       1504226021        60          795      25  0.017673       252
# ...            ...       ...          ...     ...       ...       ...
# 347695  1509493938       810          870      29  0.001157         0
# 347696  1509493953       825          870      29  0.001157         0
# 347697  1509493968       840          870      29  0.001157         0
# 347698  1509493983       855          870      29  0.001157         0
# 347699  1509493998       870          870      29  0.001157         0
#
#            heading  baroaltitude        lat         lon  ...  \
# 0       168.457474   2957.280132 -28.409528  151.931314  ...
# ...
